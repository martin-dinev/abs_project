# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import logging

logging.getLogger("tensorflow").setLevel(logging.ERROR)  # this goes *before* tf import

import numpy as np
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPool2D, Reshape
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError, MSE

import tensorflow as tf

os.environ['AUTOGRAPH_VERBOSITY'] = '1'
tf.autograph.set_verbosity(0)

from tqdm import tqdm

from kaggle_environments import make
from deep_q_learning import DDQN
from my_utils import my_train, my_evaluate, mean_reward
# Out:
# Loading environment lux_ai_s2 failed: No module named 'pettingzoo'

# %%
env = make("connectx", debug=False)

state_space_shape = (6, 7)
num_actions = 7
num_episodes = 1000
learning_rate = 0.01
discount_factor = 0.99
batch_size = 256
memory_size = 2048

epsilon = 1
epsilon_min = 0.1
epsilon_decay = 1.5 * (epsilon - epsilon_min) / num_episodes

# %%
from tensorflow.python.keras.layers import Conv2D


def build_model():
    i = Input(shape=state_space_shape)
    r = Reshape(target_shape=(6, 7, 1))(i)
    cd = Conv2D(8, kernel_size=(2, 2))(r)
    cd = Conv2D(8, kernel_size=(2, 2))(cd)
    cd = Conv2D(8, kernel_size=(2, 3))(cd)
    cd = Conv2D(8, kernel_size=(3, 3))(cd)
    cd = Reshape(target_shape=(8,))(cd)
    l = Dense(14)(cd)
    l = Dense(7)(l)

    m = Model(inputs=i, outputs=l)
    m.compile(Adam(learning_rate=learning_rate), loss=MeanSquaredError())

    return m

# %%
model = build_model()
target_model = build_model()
agent = DDQN(state_space_shape, num_actions, model, target_model, learning_rate, discount_factor, batch_size,
            memory_size)

# %%
def my_agent(observation, _):
    _state = process_state(observation)
    _action = agent.get_action(_state, 0)
    _action = postprocess_action(_action)
    return _action


def fixed_agent(observation, _):
    return 3

# %%
def process_state(_state):
    return np.asarray(_state.board).reshape((6, 7))


def preprocess_reward(_reward):
    return (10 if _reward == 1 else 1 if _reward == 0 else -10) if _reward is not None else -100


def postprocess_action(_action):
    return round(_action)

# %%
configuration = {
    "num_episodes": 200,
    "process_state": process_state, "process_reward": preprocess_reward, "process_action": postprocess_action,
    "epsilon": epsilon, "epsilon_decay": epsilon_decay, "epsilon_min": epsilon_min,
    "save_iter": 200, "save_name": "connectx-DDQN", "prev_count": 0
}

my_train(agent, opponent="random", **configuration)
agent.save('connectx-DDQN', 1000)

print("My Agent vs Random Agent:", mean_reward(my_evaluate("connectx", [my_agent, "random"])))
print("My Agent vs Negamax Agent:", mean_reward(my_evaluate("connectx", [my_agent, "negamax"])))
print("My Agent vs Fixed Agent", mean_reward(my_evaluate("connectx", [my_agent, fixed_agent])))
# Out:
#   2%|▎         | 5/200 [00:27<17:43,  5.46s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 8
#       1 configuration = {
#       2     "num_episodes": 200,
#       3     "process_state": process_state, "process_reward": preprocess_reward, "process_action": postprocess_action,
#       4     "epsilon": epsilon, "epsilon_decay": epsilon_decay, "epsilon_min": epsilon_min,
#       5     "save_iter": 200, "save_name": "connectx-DDQN", "prev_count": 0
#       6 }
# ----> 8 my_train(agent, opponent="random", **configuration)
#       9 agent.save('connectx-DDQN', 1000)
#      11 print("My Agent vs Random Agent:", mean_reward(my_evaluate("connectx", [my_agent, "random"])))
#
# File ~\Desktop\abs_project\code2\my_utils.py:25, in my_train(agent, opponent, num_episodes, process_state, process_reward, process_action, epsilon, epsilon_decay, epsilon_min, save_iter, prev_count, save_name)
#      23     agent.update_memory(state, action, process_reward(reward), new_state, done)
#      24     state = new_state
# ---> 25 agent.train()
#      26 agent.update_target_model()
#      27 if save_iter is not None and (i+1)%save_iter == 0:
#
# File ~\Desktop\abs_project\code2\deep_q_learning.py:217, in DDQN.train(self)
#     215     else:
#     216         next_state = next_state.reshape(1, self.state_space_shape)
# --> 217     max_action = np.argmax(self.model.predict(next_state, verbose=0)[0])
#     218     max_future_q = (reward + self.discount_factor *
#     219                     self.target_model.predict(next_state, verbose=0)[0][max_action])
#     220 if isinstance(self.state_space_shape, tuple):
#
# File ~\.conda\envs\code2\lib\site-packages\keras\src\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\.conda\envs\code2\lib\site-packages\keras\src\engine\training.py:2603, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2594     except ValueError:
#    2595         warnings.warn(
#    2596             "Using Model.predict with MultiWorkerMirroredStrategy "
#    2597             "or TPUStrategy and AutoShardPolicy.FILE might lead to "
#    (...)
#    2600             stacklevel=2,
#    2601         )
# -> 2603 data_handler = data_adapter.get_data_handler(
#    2604     x=x,
#    2605     batch_size=batch_size,
#    2606     steps_per_epoch=steps,
#    2607     initial_epoch=0,
#    2608     epochs=1,
#    2609     max_queue_size=max_queue_size,
#    2610     workers=workers,
#    2611     use_multiprocessing=use_multiprocessing,
#    2612     model=self,
#    2613     steps_per_execution=self._steps_per_execution,
#    2614 )
#    2616 # Container that configures and calls `tf.keras.Callback`s.
#    2617 if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File ~\.conda\envs\code2\lib\site-packages\keras\src\engine\data_adapter.py:1678, in get_data_handler(*args, **kwargs)
#    1676         return _ClusterCoordinatorExactEvalDataHandler(*args, **kwargs)
#    1677     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1678 return DataHandler(*args, **kwargs)
#
# File ~\.conda\envs\code2\lib\site-packages\keras\src\engine\data_adapter.py:1285, in DataHandler.__init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute, pss_evaluation_shards)
#    1282     self._steps_per_execution = steps_per_execution
#    1284 adapter_cls = select_data_adapter(x, y)
# -> 1285 self._adapter = adapter_cls(
#    1286     x,
#    1287     y,
#    1288     batch_size=batch_size,
#    1289     steps=steps_per_epoch,
#    1290     epochs=epochs - initial_epoch,
#    1291     sample_weights=sample_weight,
#    1292     shuffle=shuffle,
#    1293     max_queue_size=max_queue_size,
#    1294     workers=workers,
#    1295     use_multiprocessing=use_multiprocessing,
#    1296     distribution_strategy=tf.distribute.get_strategy(),
#    1297     model=model,
#    1298     pss_evaluation_shards=pss_evaluation_shards,
#    1299 )
#    1301 strategy = tf.distribute.get_strategy()
#    1303 self._current_step = 0
#
# File ~\.conda\envs\code2\lib\site-packages\keras\src\engine\data_adapter.py:314, in TensorLikeDataAdapter.__init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     307     return indices
#     309 # We prefetch a single element. Computing large permutations can take
#     310 # quite a while so we don't want to wait for prefetching over an epoch
#     311 # boundary to trigger the next permutation. On the other hand, too many
#     312 # simultaneous shuffles can contend on a hardware level and degrade all
#     313 # performance.
# --> 314 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     316 def slice_batch_indices(indices):
#     317     """Convert a Tensor of indices into a dataset of batched indices.
#     318
#     319     This step can be accomplished in several ways. The most natural is
#    (...)
#     331       A Dataset of batched indices.
#     332     """
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\dataset_ops.py:2268, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, name)
#    2264 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2265 # dataset_ops).
#    2266 # pylint: disable=g-import-not-at-top,protected-access
#    2267 from tensorflow.python.data.ops import map_op
# -> 2268 return map_op._map_v2(
#    2269     self,
#    2270     map_func,
#    2271     num_parallel_calls=num_parallel_calls,
#    2272     deterministic=deterministic,
#    2273     name=name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\map_op.py:37, in _map_v2(input_dataset, map_func, num_parallel_calls, deterministic, name)
#      34   if deterministic is not None and not debug_mode.DEBUG_MODE:
#      35     warnings.warn("The `deterministic` argument has no effect unless the "
#      36                   "`num_parallel_calls` argument is specified.")
# ---> 37   return _MapDataset(
#      38       input_dataset, map_func, preserve_cardinality=True, name=name)
#      39 else:
#      40   return _ParallelMapDataset(
#      41       input_dataset,
#      42       map_func,
#    (...)
#      45       preserve_cardinality=True,
#      46       name=name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\map_op.py:107, in _MapDataset.__init__(self, input_dataset, map_func, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#     105 self._use_inter_op_parallelism = use_inter_op_parallelism
#     106 self._preserve_cardinality = preserve_cardinality
# --> 107 self._map_func = structured_function.StructuredFunctionWrapper(
#     108     map_func,
#     109     self._transformation_name(),
#     110     dataset=input_dataset,
#     111     use_legacy_function=use_legacy_function)
#     112 self._name = name
#     113 variant_tensor = gen_dataset_ops.map_dataset(
#     114     input_dataset._variant_tensor,  # pylint: disable=protected-access
#     115     self._map_func.function.captured_inputs,
#    (...)
#     118     preserve_cardinality=self._preserve_cardinality,
#     119     **self._common_args)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\structured_function.py:265, in StructuredFunctionWrapper.__init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#     258       warnings.warn(
#     259           "Even though the `tf.config.experimental_run_functions_eagerly` "
#     260           "option is set, this option does not apply to tf.data functions. "
#     261           "To force eager execution of tf.data functions, please use "
#     262           "`tf.data.experimental.enable_debug_mode()`.")
#     263     fn_factory = trace_tf_function(defun_kwargs)
# --> 265 self._function = fn_factory()
#     266 # There is no graph to add in eager mode.
#     267 add_to_graph &= not context.executing_eagerly()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1198, in Function.get_concrete_function(self, *args, **kwargs)
#    1196 def get_concrete_function(self, *args, **kwargs):
#    1197   # Implements GenericFunction.get_concrete_function.
# -> 1198   concrete = self._get_concrete_function_garbage_collected(*args, **kwargs)
#    1199   concrete._garbage_collector.release()  # pylint: disable=protected-access
#    1200   return concrete
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:1178, in Function._get_concrete_function_garbage_collected(self, *args, **kwargs)
#    1176   if self._variable_creation_fn is None:
#    1177     initializers = []
# -> 1178     self._initialize(args, kwargs, add_initializers_to=initializers)
#    1179     self._initialize_uninitialized_variables(initializers)
#    1181 if self._created_variables:
#    1182   # In this case we have created variables on the first call, so we run the
#    1183   # version which is guaranteed to never create variables.
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:687, in Function._initialize(self, args, kwds, add_initializers_to)
#     684 self._variable_creation_fn._name = self._name  # pylint: disable=protected-access
#     685 # Force the definition of the function for these arguments
#     686 self._concrete_variable_creation_fn = (
# --> 687     self._variable_creation_fn.get_concrete_function(args, kwds)
#     688 )
#     690 def invalid_creator_scope(*unused_args, **unused_kwds):
#     691   """Disables variable creation."""
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:187, in TracingCompiler.get_concrete_function(self, args, kwargs, bind_graph_to_function)
#     182   args, kwargs = function_type_utils.bind_function_inputs(
#     183       args, kwargs, self._function_type, self._default_values
#     184   )
#     186 with self._lock:
# --> 187   concrete_function, _ = self._maybe_define_concrete_function(args, kwargs)
#     188   _set_arg_keywords(concrete_function)
#     190 if not bind_graph_to_function:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:162, in TracingCompiler._maybe_define_concrete_function(self, args, kwargs)
#     159   args = self.input_signature
#     160   kwargs = {}
# --> 162 return self._maybe_define_function(args, kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:334, in TracingCompiler._maybe_define_function(self, args, kwargs)
#     332 else:
#     333   target_func_type = lookup_func_type
# --> 334 concrete_function = self._create_concrete_function(
#     335     target_func_type, lookup_func_context, func_graph
#     336 )
#     338 self._function_cache.add(concrete_function, current_func_context)
#     340 return concrete_function, filtered_flat_args
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compiler.py:214, in TracingCompiler._create_concrete_function(self, function_type, type_context, func_graph)
#     209 with func_graph.as_default():
#     210   placeholder_bound_args = function_type.placeholder_arguments(
#     211       placeholder_context
#     212   )
# --> 214 traced_func_graph = func_graph_module.func_graph_from_py_func(
#     215     self._name,
#     216     self._python_function,
#     217     placeholder_bound_args.args,
#     218     placeholder_bound_args.kwargs,
#     219     None,
#     220     func_graph=func_graph,
#     221     arg_names=function_type_utils.to_arg_names(function_type),
#     222     create_placeholders=False,
#     223 )
#     225 transform.apply_func_graph_transforms(traced_func_graph)
#     227 graph_capture_container = traced_func_graph.function_captures
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\func_graph.py:1055, in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, create_placeholders)
#    1052   return x
#    1054 _, original_func = tf_decorator.unwrap(python_func)
# -> 1055 func_outputs = python_func(*func_args, **func_kwargs)
#    1057 # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#    1058 # TensorArrays and `None`s.
#    1059 func_outputs = variable_utils.convert_variables_to_tensors(func_outputs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:590, in Function._compiler_with_scope.<locals>.wrapped_fn(*args, **kwds)
#     586 with default_graph._variable_creator_scope(scope, priority=50):  # pylint: disable=protected-access
#     587   # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     588   # the function a weak reference to itself to avoid a reference cycle.
#     589   with OptionalXlaContext(compile_with_xla):
# --> 590     out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     591   return out
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\structured_function.py:231, in StructuredFunctionWrapper.__init__.<locals>.trace_tf_function.<locals>.wrapped_fn(*args)
#     230 def wrapped_fn(*args):  # pylint: disable=missing-docstring
# --> 231   ret = wrapper_helper(*args)
#     232   ret = structure.to_tensor_list(self._output_structure, ret)
#     233   return [ops.convert_to_tensor(t) for t in ret]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\data\ops\structured_function.py:161, in StructuredFunctionWrapper.__init__.<locals>.wrapper_helper(*args)
#     159 if not _should_unpack(nested_args):
#     160   nested_args = (nested_args,)
# --> 161 ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#     162 ret = variable_utils.convert_variables_to_tensors(ret)
#     163 if _should_pack(ret):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\impl\api.py:690, in convert.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     688 try:
#     689   with conversion_ctx:
# --> 690     return converted_call(f, args, kwargs, options=options)
#     691 except Exception as e:  # pylint:disable=broad-except
#     692   if hasattr(e, 'ag_error_metadata'):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\impl\api.py:377, in converted_call(f, args, kwargs, caller_fn_scope, options)
#     374   return _call_unconverted(f, args, kwargs, options)
#     376 if not options.user_requested and conversion.is_allowlisted(f):
# --> 377   return _call_unconverted(f, args, kwargs, options)
#     379 # internal_convert_user_code is for example turned off when issuing a dynamic
#     380 # call conversion from generated code while in nonrecursive mode. In that
#     381 # case we evidently don't want to recurse, but we still have to convert
#     382 # things like builtins.
#     383 if not options.internal_convert_user_code:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\autograph\impl\api.py:459, in _call_unconverted(f, args, kwargs, options, update_cache)
#     456   return f.__self__.call(args, kwargs)
#     458 if kwargs is not None:
# --> 459   return f(*args, **kwargs)
#     460 return f(*args)
#
# File ~\.conda\envs\code2\lib\site-packages\keras\src\engine\data_adapter.py:304, in TensorLikeDataAdapter.__init__.<locals>.permutation(_)
#     300 def permutation(_):
#     301     # It turns out to be more performant to make a new set of indices
#     302     # rather than reusing the same range Tensor. (presumably because of
#     303     # buffer forwarding.)
# --> 304     indices = tf.range(num_samples, dtype=tf.int64)
#     305     if shuffle and shuffle != "batch":
#     306         indices = tf.random.shuffle(indices)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\math_ops.py:2181, in range(start, limit, delta, dtype, name)
#    2179   start = ops.convert_to_tensor(start, dtype=dtype, name="start")
#    2180 if not isinstance(limit, ops.Tensor):
# -> 2181   limit = ops.convert_to_tensor(limit, dtype=dtype, name="limit")
#    2182 if not isinstance(delta, ops.Tensor):
#    2183   delta = ops.convert_to_tensor(delta, dtype=dtype, name="delta")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:703, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     701 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     702 preferred_dtype = preferred_dtype or dtype_hint
# --> 703 return tensor_conversion_registry.convert(
#     704     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     705 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\constant_op.py:327, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     324 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     325                                          as_ref=False):
#     326   _ = as_ref
# --> 327   return constant(v, dtype=dtype, name=name)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\constant_op.py:266, in constant(value, dtype, shape, name)
#     169 @tf_export("constant", v1=[])
#     170 def constant(value, dtype=None, shape=None, name="Const"):
#     171   """Creates a constant tensor from a tensor-like object.
#     172
#     173   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     264     ValueError: if called on a symbolic tensor.
#     265   """
# --> 266   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     267                         allow_broadcast=True)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\constant_op.py:280, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     277       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     278   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 280 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     281     value, dtype, shape, name, verify_shape, allow_broadcast
#     282 )
#     283 return const_tensor
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:272, in _create_graph_constant(value, dtype, shape, name, verify_shape, allow_broadcast)
#     270 dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     271 attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 272 const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     273     "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     275 if op_callbacks.should_invoke_op_callbacks():
#     276   # TODO(b/147670703): Once the special-op creation code paths
#     277   # are unified. Remove this `if` block.
#     278   callback_outputs = op_callbacks.invoke_op_callbacks(
#     279       "Const", tuple(), attrs, (const_tensor,), op_name=name, graph=g)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\func_graph.py:670, in FuncGraph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     668   inp = self.capture(inp)
#     669   captured_inputs.append(inp)
# --> 670 return super()._create_op_internal(  # pylint: disable=protected-access
#     671     op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     672     compute_device)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:2647, in Graph._create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    2644 # _create_op_helper mutates the new Operation. `_mutation_lock` ensures a
#    2645 # Session.run call cannot occur between creating and mutating the op.
#    2646 with self._mutation_lock():
# -> 2647   ret = Operation.from_node_def(
#    2648       node_def,
#    2649       self,
#    2650       inputs=inputs,
#    2651       output_types=dtypes,
#    2652       control_inputs=control_inputs,
#    2653       input_types=input_types,
#    2654       original_op=self._default_original_op,
#    2655       op_def=op_def,
#    2656   )
#    2657   self._create_op_helper(ret, compute_device=compute_device)
#    2658 return ret
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:1152, in Operation.from_node_def(***failed resolving arguments***)
#    1149     control_input_ops.append(control_op)
#    1151 # Initialize c_op from node_def and other inputs
# -> 1152 c_op = _create_c_op(g, node_def, inputs, control_input_ops, op_def=op_def)
#    1153 self = Operation(c_op, SymbolicTensor)
#    1154 self._init(g)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:1009, in _create_c_op(graph, node_def, inputs, control_inputs, op_def, extract_traceback)
#    1005   pywrap_tf_session.TF_SetAttrValueProto(op_desc, compat.as_str(name),
#    1006                                          serialized)
#    1008 try:
# -> 1009   c_op = pywrap_tf_session.TF_FinishOperation(op_desc)
#    1010 except errors.InvalidArgumentError as e:
#    1011   # Convert to ValueError for backwards compatibility.
#    1012   raise ValueError(e.message)
#
# KeyboardInterrupt:
